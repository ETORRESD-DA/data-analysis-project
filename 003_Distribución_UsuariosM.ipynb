# %%
#Libraries import
import csv
from datetime import datetime
import requests
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
# Carga Archivo
df_covid = pd.read_csv('tmp/covid19_tweets.csv',encoding="utf-8")

# %%
#Limpiar data frame

#Convertimos locacion a string
casting_dict = {
    "user_name":'string',
    "user_location":'string'
}
df_covid_casted=df_covid.astype(casting_dict)
#quitar ""
df_covid_casted['user_name'] = df_covid_casted['user_name'].str.strip()
#title
df_covid_casted['user_location'] = df_covid_casted['user_location'].str.title()
#Filtrar Data Frame valores nan
df_covid_filter=df_covid_casted["user_location"] != "Nan" 
df_covid_casted=df_covid_casted[df_covid_filter]

# %%
#df_covid_casted=df_covid_casted['user_location'].map(get_with_comma)


#df_covid_casted=df_covid_filter2['user_location'].map(get_with_comma)

#df_covid_casted["evaluaSplit"]=df_covid_casted['user_location'].map(get_with_comma)
#df_covid_casted

#df_covid_casted=df_covid_casted[split]

# %%
#df_covid_casted=[df_covid_filter2,split]

# %%
#df_covid_casted

# %%
#df_covid_casted["user_location"]=[df_covid_filter2]

# %%
df_covid_casted
# Out:
#                            user_name         user_location  \
# 0                             ᏉᎥ☻լꂅϮ            Astroworld
# 1                      Tom Basile 🇺🇸          New York, Ny
# 2                    Time4fisticuffs      Pewee Valley, Ky
# 3                        ethel mertz  Stuck In The Middle
# 4                           DIPR-J&K     Jammu And Kashmir
# ...                              ...                   ...
# 166650                @d_alpha_alpha           Chicago, Il
# 166652  Public Health is the Economy         Sarasota, Fl
# 166653           Farheen Qurashi, MD         Baltimore, Md
# 166654                  Alf O'Kenney          Montréal, Qc
# 166655         J Michael 🇺🇸🏋🏼🏃🏼‍♂️🏝🚔           Connecticut
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# 3       #Browns #Indians #ClevelandProud #[]_[] #Cavs ...
# 4       🖊️Official Twitter handle of Department of Inf...
# ...                                                   ...
# 166650                                                NaN
# 166652  All the marketing or growth hacks in the world...
# 166653  (She/Her) Trauma/Critical Care Surgeon. Wife, ...
# 166654  Dans ses écrits / un sage italien / dit que le...
# 166655  Ethics Def: Doing the right thing when nobody ...
#
#                user_created  user_followers  user_friends  user_favourites  \
# 0       2017-05-26 05:46:42             624           950            18775
# 1       2009-04-16 20:06:23            2253          1677               24
# 2       2009-02-28 18:57:41            9275          9525             7254
# 3       2019-03-07 01:45:06             197           987             1488
# 4       2017-02-12 06:45:15          101009           168              101
# ...                     ...             ...           ...              ...
# 166650  2012-03-04 18:58:51             263           181              519
# 166652  2016-08-12 20:39:08           10875          7351           500315
# 166653  2020-08-03 12:37:00              35           118              769
# 166654  2019-10-08 14:12:37              13           139              101
# 166655  2012-09-22 19:22:39             284           317             8065
#
#         user_verified                 date  \
# 0               False  2020-07-25 12:27:21
# 1                True  2020-07-25 12:27:17
# 2               False  2020-07-25 12:27:14
# 3               False  2020-07-25 12:27:10
# 4               False  2020-07-25 12:27:08
# ...               ...                  ...
# 166650          False  2020-08-22 00:16:14
# 166652          False  2020-08-22 00:16:08
# 166653          False  2020-08-22 00:16:03
# 166654          False  2020-08-22 00:16:00
# 166655          False  2020-08-22 00:16:00
#
#                                                      text  \
# 0       If I smelled the scent of hand sanitizers toda...
# 1       Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2       @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3       @brookbanktv The one gift #COVID19 has give me...
# 4       25 July : Media Bulletin on Novel #CoronaVirus...
# ...                                                   ...
# 166650  Keep it up with your bullshiting, I take care ...
# 166652  Ignoring your core civic duty to fellow Florid...
# 166653  When people around me do wat a mask, it makes ...
# 166654  Stream of #COVID19 thoughts:\n\n• First waves ...
# 166655  @NBSaphierMD Doc....serious question: Why don’...
#
#                                  hashtags               source  is_retweet
# 0                                     NaN   Twitter for iPhone       False
# 1                                     NaN  Twitter for Android       False
# 2                             ['COVID19']  Twitter for Android       False
# 3                             ['COVID19']   Twitter for iPhone       False
# 4       ['CoronaVirusUpdates', 'COVID19']  Twitter for Android       False
# ...                                   ...                  ...         ...
# 166650                        ['covid19']            Instagram       False
# 166652                        ['covid19']  Twitter for Android       False
# 166653              ['MaskUp', 'COVID19']   Twitter for iPhone       False
# 166654                        ['COVID19']  Twitter for Android       False
# 166655                                NaN     Twitter for iPad       False
#
# [132735 rows x 13 columns]

# %%
#df_covid_casted[split]

# %%
#df_covid_casted=df_covid_casted['user_location'].apply(split)

# %%
df_covid_casted
# Out:
#                            user_name         user_location  \
# 0                             ᏉᎥ☻լꂅϮ            Astroworld
# 1                      Tom Basile 🇺🇸          New York, Ny
# 2                    Time4fisticuffs      Pewee Valley, Ky
# 3                        ethel mertz  Stuck In The Middle
# 4                           DIPR-J&K     Jammu And Kashmir
# ...                              ...                   ...
# 166650                @d_alpha_alpha           Chicago, Il
# 166652  Public Health is the Economy         Sarasota, Fl
# 166653           Farheen Qurashi, MD         Baltimore, Md
# 166654                  Alf O'Kenney          Montréal, Qc
# 166655         J Michael 🇺🇸🏋🏼🏃🏼‍♂️🏝🚔           Connecticut
#
#                                          user_description  \
# 0       wednesday addams as a disney princess keepin i...
# 1       Husband, Father, Columnist & Commentator. Auth...
# 2       #Christian #Catholic #Conservative #Reagan #Re...
# 3       #Browns #Indians #ClevelandProud #[]_[] #Cavs ...
# 4       🖊️Official Twitter handle of Department of Inf...
# ...                                                   ...
# 166650                                                NaN
# 166652  All the marketing or growth hacks in the world...
# 166653  (She/Her) Trauma/Critical Care Surgeon. Wife, ...
# 166654  Dans ses écrits / un sage italien / dit que le...
# 166655  Ethics Def: Doing the right thing when nobody ...
#
#                user_created  user_followers  user_friends  user_favourites  \
# 0       2017-05-26 05:46:42             624           950            18775
# 1       2009-04-16 20:06:23            2253          1677               24
# 2       2009-02-28 18:57:41            9275          9525             7254
# 3       2019-03-07 01:45:06             197           987             1488
# 4       2017-02-12 06:45:15          101009           168              101
# ...                     ...             ...           ...              ...
# 166650  2012-03-04 18:58:51             263           181              519
# 166652  2016-08-12 20:39:08           10875          7351           500315
# 166653  2020-08-03 12:37:00              35           118              769
# 166654  2019-10-08 14:12:37              13           139              101
# 166655  2012-09-22 19:22:39             284           317             8065
#
#         user_verified                 date  \
# 0               False  2020-07-25 12:27:21
# 1                True  2020-07-25 12:27:17
# 2               False  2020-07-25 12:27:14
# 3               False  2020-07-25 12:27:10
# 4               False  2020-07-25 12:27:08
# ...               ...                  ...
# 166650          False  2020-08-22 00:16:14
# 166652          False  2020-08-22 00:16:08
# 166653          False  2020-08-22 00:16:03
# 166654          False  2020-08-22 00:16:00
# 166655          False  2020-08-22 00:16:00
#
#                                                      text  \
# 0       If I smelled the scent of hand sanitizers toda...
# 1       Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2       @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3       @brookbanktv The one gift #COVID19 has give me...
# 4       25 July : Media Bulletin on Novel #CoronaVirus...
# ...                                                   ...
# 166650  Keep it up with your bullshiting, I take care ...
# 166652  Ignoring your core civic duty to fellow Florid...
# 166653  When people around me do wat a mask, it makes ...
# 166654  Stream of #COVID19 thoughts:\n\n• First waves ...
# 166655  @NBSaphierMD Doc....serious question: Why don’...
#
#                                  hashtags               source  is_retweet
# 0                                     NaN   Twitter for iPhone       False
# 1                                     NaN  Twitter for Android       False
# 2                             ['COVID19']  Twitter for Android       False
# 3                             ['COVID19']   Twitter for iPhone       False
# 4       ['CoronaVirusUpdates', 'COVID19']  Twitter for Android       False
# ...                                   ...                  ...         ...
# 166650                        ['covid19']            Instagram       False
# 166652                        ['covid19']  Twitter for Android       False
# 166653              ['MaskUp', 'COVID19']   Twitter for iPhone       False
# 166654                        ['COVID19']  Twitter for Android       False
# 166655                                NaN     Twitter for iPad       False
#
# [132735 rows x 13 columns]

# %%
def get_with_comma(value):
   if ',' in value:
      return True
   
   return False

# %%
def split()
    df_covid_casted[['user_location', 'Country']]=df_covid_casted['user_location'].str.split(',', 1, expand=True)
# Out:
#   File "<ipython-input-405-8852aff82a63>", line 1
#     def split()
#                ^
# SyntaxError: invalid syntax

# %%
#Funcion agrupa data frame 
def agrupado_usuarios_ciudad():
    df_agrupado=df_covid_casted
    df_agrupado["count"]=df_agrupado["user_name"]
    df_agrupado=df_agrupado.groupby(["user_location"])['count'].count().reset_index(name='user_count')
    return df_agrupado

# %%
#Funcion ordena data frame
def ordenado_num_usuarios(df_agrupado_usuarios_ciudad):
    df_ordenado=df_agrupado_usuarios_ciudad.sort_values(['user_count'],ascending=False)
    return df_ordenado

# %%
df_agrupado_usuarios_ciudad=agrupado_usuarios_ciudad()
df_ordenado=ordenado_num_usuarios(df_agrupado_usuarios_ciudad)
df_ordenado
# Out:
#                        user_location  user_count
# 9801                           India        3587
# 21989                  United States        2258
# 14606               New Delhi, India        1637
# 23739                      Worldwide        1568
# 14042                  Mumbai, India        1300
# ...                              ...         ...
# 11973               Live Free Or Die           1
# 11975            Live Free Or Die Nh           1
# 11976          Live From Los Angeles           1
# 11977  Live In Honolulu & East Coast           1
# 12408       Look Up At The Night Sky           1
#
# [24817 rows x 2 columns]
